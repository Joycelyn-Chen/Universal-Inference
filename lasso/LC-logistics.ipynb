# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_file = 'results.csv'

# %%
df = pd.read_csv(csv_file)

# %%
len(df[df['LC'] > 100])
# Out:
# 126

# %%
len(df)
# Out:
# 14580

# %%
plt.hist(df['LC'])
# Out:
# (array([1.4577e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([0.00000000e+000, 1.32410633e+166, 2.64821265e+166, 3.97231898e+166,
#         5.29642531e+166, 6.62053164e+166, 7.94463796e+166, 9.26874429e+166,
#         1.05928506e+167, 1.19169569e+167, 1.32410633e+167]),
#  <BarContainer object of 10 artists>)
